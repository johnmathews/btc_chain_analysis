# %% [markdown]
# # The number of unconfirmed transactions on the Bitcoin blockchain quickly increased in May 2017 before falling in June 2017. Why?

# %%
from IPython.display import HTML
HTML('''<script>
code_show=false; 
function code_toggle() {
 if (code_show){
 $('div.input').show();
 } else {
 $('div.input').hide();
 }
 code_show =! code_show
} 
$( document ).ready(code_toggle);
</script>

<font> The Python code is hidden by default, if you'd like to see it, click <a href="javascript:code_toggle()">here</a>.</font>
''')
# Out:
# <script>
# code_show=false;
# function code_toggle() {
#  if (code_show){
#  $('div.input').show();
#  } else {
#  $('div.input').hide();
#  }
#  code_show =! code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <font color=#33cc33><i>The Python code is hidden by default, if you'd like to see it, click <a href="javascript:code_toggle()">here</a>.</i></font>
# </script>

# %% [raw]
# <script>
# window.onload = function() {
#   code_toggle();
# };
# </script>

# %%
## Steup - libraries
import quandl
#import numpy as np
#import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt

import plotly
import plotly.plotly as py
import plotly.graph_objs as go

#import plotly.figure_factory as ff
#from plotly.graph_objs import *
#import plotly.tools as tls
#tls.embed('https://plot.ly/~cufflinks/8')

# %%
## Setup - appearance
# add a ; at the end to suppress function output (when plotting)
# matplotlib.style.use('ggplot')

# get rid of the annoying 'SettingWithCopy' warning
pd.options.mode.chained_assignment = None  # default='warn'

# more than one print of an unassigned variable
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Display plot results inline, not in a separate window
# %matplotlib inline
# %pylab inline

# Set the size of all figures
pylab.rcParams['figure.figsize'] = (14, 5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# quandl API
quandl.ApiConfig.api_key = "sSTsxvoy-i_fotUWXYoh"

# plotly API
plotly.tools.set_credentials_file(username='mthwsjc', api_key='KKfrs90UfQsa98gg52ak')

# %% [markdown]
# ## Number of transactions awaiting confirmation (Mempool size)

# %%
# import mempool data downloaded from https://blockchain.info/charts/mempool-count?timespan=all
mempool = pd.read_csv(
    'mempool-count.csv', 
    header=None, 
    names=['DateTime','size'], 
    parse_dates=[0], 
    infer_datetime_format=True
    )

# split the datetime to date and time
temp = pd.DatetimeIndex(mempool['DateTime'])
mempool['Date'] = temp.date
mempool['Time'] = temp.time
del mempool['DateTime']

# reorder the columns
cols = ['Date','Time','size']
mempool = mempool[cols]
trial = mempool
mempool.set_index('Date', inplace=True)

# %%
# there are 3 values per day. Should I take the average per day, or the middle per day?
# get average mempool size for each day
mempool = mempool.groupby([mempool.index.get_level_values('Date')]).mean()

# %%
mempool.head()
# Out:
#                size
# Date
# 2016-04-24  2116.50
# 2016-04-25  1040.75
# 2016-04-26  2378.00
# 2016-04-27  2220.00
# 2016-04-28  3416.00

# %%
# smooth the plot by showing the 5 day rolling average
mempool['size_av']=mempool['size'].rolling(window=5).mean();
data = [go.Scatter( x=mempool.index.get_level_values('Date'), y=mempool['size_av'] )]
py.iplot(data, filename='btc_mempool')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mthwsjc/7.embed" height="525px" width="100%"></iframe>

# %%
trial.head()
data = [go.Scatter( x=df['Date'], y=df['AAPL.Close'] )]
# Out:
# Date
# 2016-04-24        NaN
# 2016-04-25        NaN
# 2016-04-26        NaN
# 2016-04-27        NaN
# 2016-04-28    2234.25
# Name: size, dtype: float64
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-27-2e6ee0c24fe7> in <module>()
#       1 trial.head()
#       2
# ----> 3 py.iplot(trial, filename='jupyter/trial')
#
# /usr/local/lib/python3.6/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     132     if 'auto_open' not in plot_options:
#     133         plot_options['auto_open'] = False
# --> 134     url = plot(figure_or_data, **plot_options)
#     135
#     136     if isinstance(figure_or_data, dict):
#
# /usr/local/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     193
#     194     """
# --> 195     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     196     for entry in figure['data']:
#     197         if ('type' in entry) and (entry['type'] == 'scattergl'):
#
# /usr/local/lib/python3.6/site-packages/plotly/tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#    1377         figure = {'data': figure_or_data}
#    1378     else:
# -> 1379         raise exceptions.PlotlyError("The `figure_or_data` positional "
#    1380                                      "argument must be either "
#    1381                                      "`dict`-like or `list`-like.")
#
# PlotlyError: The `figure_or_data` positional argument must be either `dict`-like or `list`-like.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv")

data = [go.Scatter( x=df['Date'], y=df['AAPL.Close'] )]

py.iplot(data, filename='pandas-time-series')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mthwsjc/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Median time taken for transactions to be accepted into a block (Minutes)

# %%
# The Dailiy Median time taken for transactions to be accepted into a block, presumably in minutes
ATRCT = quandl.get("BCHAIN/ATRCT")
ATRCT = ATRCT.loc['2016-04-24':]

# %%
ATRCT['Value'].rolling(window=5).mean().plot(y='Median transaction acceptance time');

# %% [markdown]
# ## Average number of transactions per (1MB) block

# %%
# The average number of transactions per block.
NTRBL = quandl.get("BCHAIN/NTRBL")
NTRBL = NTRBL.loc['2016-04-24':]

# %%
NTRBL['Value'].rolling(window=5).mean().plot(y='Average number of transactions per block');

# %% [markdown]
# ## Average size of block each day (MB)

# %%
# The Average block size in MB
AVBLS = quandl.get("BCHAIN/AVBLS")

# %%
av_bs = AVBLS.loc['2016-04-24':]
av_bs['Size']=av_bs['Value']
del av_bs['Value']
# Out:
#                 Size
# Date
# 2016-04-24  0.654661
# 2016-04-25  0.728040
# 2016-04-26  0.874485
# 2016-04-27  0.813180
# 2016-04-28  0.875343

# %%
av_bs['Size'].rolling(window=5).mean().plot(y='Average block size (MB) each day');

# %% [markdown]
# ## Total value (BTC) of transactions fees earned by miners per day

# %%
# transaction fees - the total BTC value of transaction fees miners earn per day.
TRFEE = quandl.get("BCHAIN/TRFEE")

# %%
tn_fee = TRFEE.loc['2016-04-24':]
tn_fee['Fee']=tn_fee['Value']
del tn_fee['Value']
tn_fee.head()
# Out:
#                    Fee
# Date
# 2016-04-24   33.150970
# 2016-04-25   33.268655
# 2016-04-26   43.298470
# 2016-04-27  337.756398
# 2016-04-28   46.111500

# %%
#tn_fee.plot(y='Fee');
tn_fee['Fee'].rolling(window=5).mean().plot(y='Average block size (MB) each day');

# %%
alld = tn_fee
alld['Mempool'] = mempool['size']
alld.head()
# Out:
#                    Fee  Mempool
# Date
# 2016-04-24   33.150970  2116.50
# 2016-04-25   33.268655  1040.75
# 2016-04-26   43.298470  2378.00
# 2016-04-27  337.756398  2220.00
# 2016-04-28   46.111500  3416.00

# %%
alld.plot(secondary_y=['Mempool']);
